# %% [markdown]
# ### Weather API
# #### Yearly Precipitation Data Retrieval
#
# This notebook uses the OpenMeteo Weather Archive API to retrieve past weather data for any given coordinates. It aims to provide an interface that will retrieve info on year to year weather data that aligns with the yearly measures from the International Tree Ring Datasets (https://www.ncei.noaa.gov/products/paleoclimatology/tree-ring) to measure the correlation between tree ring width and precipitation.

# %% [markdown]
# First, we need to install the OpenMeteo Python wrapper, under the hood this just uses the requests library, so we can setup a requests-cache and retry configurations such that the success rate of our querying class is more reliable and faster for multiple calls on the same years.

# %%
# !pip install openmeteo-requests
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: openmeteo-requests in ./.local/lib/python3.10/site-packages (1.1.0)
# Requirement already satisfied: openmeteo-sdk>=1.4.0 in ./.local/lib/python3.10/site-packages (from openmeteo-requests) (1.6.1)
# Requirement already satisfied: requests in ./.local/lib/python3.10/site-packages (from openmeteo-requests) (2.30.0)
# Requirement already satisfied: flatbuffers>=23.0.0 in ./.local/lib/python3.10/site-packages (from openmeteo-sdk>=1.4.0->openmeteo-requests) (23.5.26)
# Requirement already satisfied: charset-normalizer<4,>=2 in ./.local/lib/python3.10/site-packages (from requests->openmeteo-requests) (3.1.0)
# Requirement already satisfied: idna<4,>=2.5 in ./.local/lib/python3.10/site-packages (from requests->openmeteo-requests) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in ./.local/lib/python3.10/site-packages (from requests->openmeteo-requests) (2.0.2)
# Requirement already satisfied: certifi>=2017.4.17 in ./.local/lib/python3.10/site-packages (from requests->openmeteo-requests) (2023.5.7)
# DEPRECATION: distro-info 1.1build1 has a non-standard version number. pip 24.0 will enforce this behaviour change. A possible replacement is to upgrade to a newer version of distro-info or contact the author to suggest that they release a version with a conforming version number. Discussion can be found at https://github.com/pypa/pip/issues/12063

# %%
# !pip install requests-cache retry-requests
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: requests-cache in ./.local/lib/python3.10/site-packages (1.1.1)
# Requirement already satisfied: retry-requests in ./.local/lib/python3.10/site-packages (2.0.0)
# Requirement already satisfied: attrs>=21.2 in ./.local/lib/python3.10/site-packages (from requests-cache) (23.1.0)
# Requirement already satisfied: cattrs>=22.2 in ./.local/lib/python3.10/site-packages (from requests-cache) (23.2.2)
# Requirement already satisfied: platformdirs>=2.5 in ./.local/lib/python3.10/site-packages (from requests-cache) (3.10.0)
# Requirement already satisfied: requests>=2.22 in ./.local/lib/python3.10/site-packages (from requests-cache) (2.30.0)
# Requirement already satisfied: url-normalize>=1.4 in ./.local/lib/python3.10/site-packages (from requests-cache) (1.4.3)
# Requirement already satisfied: urllib3>=1.25.5 in ./.local/lib/python3.10/site-packages (from requests-cache) (2.0.2)
# Requirement already satisfied: exceptiongroup>=1.1.1 in ./.local/lib/python3.10/site-packages (from cattrs>=22.2->requests-cache) (1.2.0)
# Requirement already satisfied: typing-extensions!=4.6.3,>=4.1.0 in ./.local/lib/python3.10/site-packages (from cattrs>=22.2->requests-cache) (4.6.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in ./.local/lib/python3.10/site-packages (from requests>=2.22->requests-cache) (3.1.0)
# Requirement already satisfied: idna<4,>=2.5 in ./.local/lib/python3.10/site-packages (from requests>=2.22->requests-cache) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in ./.local/lib/python3.10/site-packages (from requests>=2.22->requests-cache) (2023.5.7)
# Requirement already satisfied: six in /usr/lib/python3/dist-packages (from url-normalize>=1.4->requests-cache) (1.16.0)
# DEPRECATION: distro-info 1.1build1 has a non-standard version number. pip 24.0 will enforce this behaviour change. A possible replacement is to upgrade to a newer version of distro-info or contact the author to suggest that they release a version with a conforming version number. Discussion can be found at https://github.com/pypa/pip/issues/12063

# %%
import pandas as pd
import numpy as np
from typing import List, Tuple
import requests_cache
from retry_requests import retry
from datetime import datetime
import openmeteo_requests

# %% [markdown]
# This is the main part of the Notebook. The WeatherAPI class comes with one public method: `get_yearly_precipitation()`. It is documented as follows:
#
# ```
# get_yearly_precipitation(year_start: int, year_end: int, longitude_latitude: Tuple, verbose=False)
#
# Takes in parameters:
#
# year_start: int -> Year to start measurement (inclusive)
# year_end: int -> Year to end measurement (inclusive)
# longitude_latitude: Tuple -> A 2 element tuple, whose first element is Longitude (int) and second is Latitude (int)
# verbose (default False): bool -> Print debug info flag
#
# The function uses the parameters to form a Pandas DataFrame that models precipitation overall sum, average, min, and max per year.
# The Dataframe contains the following columns holding the above info:
#
# year
# precipitation_sum (in mm)
# precipitation_daily_avg (in mm)
# precipitation_min (in mm)
# precipitation_max (in mm)
#
# ```
#
# The class makes it so only one Request to the API is made, hopefully helping to speed up the Pipeline. Usually, the OpenMeteo API would only give you up to every day in a year, not info on the overall year, meaning you'd have to make multiple requests for each year. By only making 1 call we're significantly reducing the wait time due to network calls to the API. It does this by creating intervals over each year to process info for only a subset of the data that correlates to each year. Then, it just uses this calculated info to create a DataFrame and return it to the caller.

# %%
class WeatherAPI:
    
    
    def __init__(self, expire_after=-1, retries=5, backoff_factor=.2):
    
        # Create Session with OpenMeteo, establish Endpoint
        self.cache = requests_cache.CachedSession('.cache', expire_after=expire_after)
        self.OpenMeteo = openmeteo_requests.Client(session=retry(self.cache, retries=retries, backoff_factor=backoff_factor))
        self.endpoint = "https://archive-api.open-meteo.com/v1/archive"
    
    
    def __process_dates(self, year_start: int, year_end: int) -> List[Tuple[int, int]]:
    
        f = "%m/%d/%Y"
        dates_list = [
            (int(datetime.strptime(f"01/01/{i}", f).timestamp()), int(datetime.strptime(f"12/31/{i}", f).timestamp())) for i in range(year_start, year_end+1)
        ]
    
        return dates_list
    
    
    def __send_request(self, packet: dict, verbose=False) -> pd.DataFrame:
    
        reponse = None
        df = pd.DataFrame()
        start_year, end_year = packet['year_start'], packet['year_end']
        dates = self.__process_dates(start_year, end_year)
        packet['start_date'] = f"{packet['year_start']}-01-01"
        packet['end_date'] = f"{packet['year_end']}-12-31"
    
        if verbose:
            print(packet)
    
        try:
            responses = self.OpenMeteo.weather_api(self.endpoint, params=packet)
        except Exception as e:
            if verbose:
                print(e)
            return df
    
        if verbose:
            
            print(f"Coordinates {responses[0].Longitude()}°E {responses[0].Latitude()}°N")
            print(f"Elevation {responses[0].Elevation()} m asl")
            print(f"Timezone {responses[0].Timezone()} {responses[0].TimezoneAbbreviation()}")
            print(f"Timezone difference to GMT+0 {responses[0].UtcOffsetSeconds()} s")

        main_df = pd.DataFrame(columns=[
            'year', 
            "precipitation_sum",
            "precipitation_avg",
            "precipitation_min",
            "precipitation_max",
            "temperature_sum",
            "temperature_avg",
            "temperature_min",
            "temperature_max"
        ])

        count = 0
        for response in responses:
            daily = response.Daily()
            temperature = daily.Variables(0).ValuesAsNumpy()
            print(temperature)
            precip = daily.Variables(1).ValuesAsNumpy()
            print(precip)
            
    
            last_ind = 0
            df_data = {
                "year": [],
                "precipitation_sum": [],
                "precipitation_avg": [],
                "precipitation_min": [],
                "precipitation_max": [],
                "temperature_sum": [],
                "temperature_avg": [],
                "temperature_min": [],
                "temperature_max": []
            }
    
            for i in range(0, end_year-start_year+1):
    
                days = len(pd.date_range(
                    start = pd.to_datetime(dates[i][0], unit = "s"),
                    end = pd.to_datetime(dates[i][1], unit = "s"),
                    freq = pd.Timedelta(seconds = 86400),
                    inclusive = "left"
                ))

    
                years_data = precip[last_ind:days+last_ind]
                temp_data = temperature[last_ind:days+last_ind]
                df_data["year"].append(i+start_year)
                df_data["precipitation_sum"].append(years_data.sum())
                df_data["precipitation_avg"].append(np.mean(years_data))
                df_data["precipitation_min"].append(np.min(years_data))
                df_data["precipitation_max"].append(np.max(years_data))
                df_data["temperature_sum"].append(temp_data.sum())
                df_data["temperature_avg"].append(np.mean(temp_data))
                df_data["temperature_min"].append(np.min(temp_data))
                df_data["temperature_max"].append(np.max(temp_data))
                
    
                last_ind=days+last_ind
    
            dataframe = pd.DataFrame(data=df_data)
            dataframe['lat'] = packet['latitude'][count]
            dataframe['lon'] = packet['longitude'][count]
            main_df = pd.concat([main_df, dataframe], ignore_index=True)
            count+=1

        print(main_df)
        return main_df
    
    
    def get_yearly_precipitation(self, year_start: int, year_end: int, long_lat: Tuple, verbose=False) -> pd.DataFrame:

        lats = [i[0] for i in long_lat]
        lons = [i[1] for i in long_lat]
        return self.__send_request({
            "latitude": lats,
            "longitude": lons,
            "year_start": year_start,
            "year_end": year_end,
            "daily": ["temperature_2m_mean", "precipitation_sum"]
        }, verbose=verbose)

# %% [markdown]
# Now all we need is an instance of this class. You can modify the default values in the constructor to adjust settings about how the class interacts with the API:
#
# expire_after: how long after the request is made to stop the waiting and return an expired request (default -1, or inifinite, to let OpenMeteo handle that)
#
# retries: how many times to retry a failed request (default 5)
#
# backoff_factor: adjust the backoff factor of the requests being sent out to OpenMeteo (default .2)
#
# Let's test it on the years from 1970-2022 in Berlin:

# %%
df = pd.read_csv('/mnt/c/Users/Michael Anderson/Desktop/random_latlong.csv')

# %%
df = df[['Latitude', 'Longitude']]

# %%
lats = list(df['Latitude'])
longs = list(df['Longitude'])

# %%
seen = set()
out = []
for i in range(len(lats)):
    lat_cur = lats[i]
    lon_cur = longs[i]

    if (lat_cur, lon_cur) not in seen:
        out.append((lat_cur, lon_cur))
        seen.add((lat_cur, lon_cur))

# %%
print(len(out))
# Out:
# 115

# %%
Weather = WeatherAPI()
df = Weather.get_yearly_precipitation(1941, 1991, out, verbose=True)
# Out:
# {'latitude': [42.90106471874291, 43.897234585733294, 44.66626254311422, 42.865496123606114, 45.5760317376105, 31.62953062571996, 30.825607236329827, 34.47364119685824, 32.10032541214999, 33.78342300707467, 35.03940240434609, 35.43159449907531, 39.11156418432981, 35.776655530834375, 38.95096244009836, 36.074775876345456, 38.041587561509125, 39.96168505673288, 38.7640450966794, 38.593735253626924, 39.84247383456071, 39.29795499093727, 39.155139686979446, 39.1646790677368, 39.15565209770326, 36.36064540991926, 39.6876530137563, 37.74452722641566, 40.06199062630843, 38.436482345342334, 36.54042703983284, 37.758987916034506
# 5860        28.875330  32.348912 -108.431940
# 5861        28.085749  32.348912 -108.431940
# 5862        30.708666  32.348912 -108.431940
# 5863        32.462833  32.348912 -108.431940
# 5864        29.731583  32.348912 -108.431940
#
# [5865 rows x 11 columns]

# %%
df
# Out:
#       year  precipitation_sum  precipitation_avg  precipitation_min  \
# 0     1941         491.299988           1.349725                0.0
# 1     1942         534.500000           1.468407                0.0
# 2     1943         500.000000           1.373626                0.0
# 3     1944         552.500000           1.513699                0.0
# 4     1945         765.999939           2.098630                0.0
# ...    ...                ...                ...                ...
# 5860  1987         367.600006           1.009890                0.0
# 5861  1988         514.299988           1.409041                0.0
# 5862  1989         265.299988           0.728846                0.0
# 5863  1990         394.599976           1.084066                0.0
# 5864  1991         491.300018           1.349725                0.0
#
#       precipitation_max  temperature_sum  temperature_avg  temperature_min  \
# 0             20.799999      1164.860596         3.200166       -16.806833
# 1             17.299999       927.408569         2.547826       -24.792252
# 2             24.499998      1242.308472         3.412935       -22.302666
# 3             16.900000       945.855957         2.591386       -16.467249
# 4             20.600000       785.907837         2.153172       -19.648502
# ...                 ...              ...              ...              ...
# 5860          33.600002      5285.867188        14.521613        -6.397583
# 5861          31.400003      5359.813477        14.684421       -11.737167
# 5862          16.300003      5892.385742        16.187874        -2.066333
# 5863          27.500000      5552.996094        15.255484        -3.170500
# 5864          31.900003      5341.085938        14.673313        -8.685084
#
#       temperature_max        lat         lon
# 0           23.526497  42.901065 -112.084051
# 1           21.316084  42.901065 -112.084051
# 2           22.901503  42.901065 -112.084051
# 3           20.266085  42.901065 -112.084051
# 4           21.930670  42.901065 -112.084051
# ...               ...        ...         ...
# 5860        28.875330  32.348912 -108.431940
# 5861        28.085749  32.348912 -108.431940
# 5862        30.708666  32.348912 -108.431940
# 5863        32.462833  32.348912 -108.431940
# 5864        29.731583  32.348912 -108.431940
#
# [5865 rows x 11 columns]

# %%
df['lat'].unique()
# Out:
# array([43.23    , 42.75    , 43.7     , 43.75    , 43.32    , 42.93    ,
#        42.78    , 43.62    , 43.73    , 44.58    , 43.47    , 43.08    ,
#        45.97    , 33.05    , 32.7     , 45.47    , 45.28    , 39.2988  ,
#        32.72    , 39.2583  , 45.55    , 45.      , 45.83    , 45.12    ,
#        47.34    , 48.51    , 44.13    , 48.18    , 45.82    , 48.59    ,
#        48.6     , 46.7     , 45.77    , 36.13    , 45.68    , 48.78    ,
#        32.8     , 39.93    , 33.355   , 39.5     , 36.8     , 40.98    ,
#        40.67    , 40.05    , 42.63    , 37.216667, 41.52    , 40.37    ,
#        32.      , 39.38    , 37.47    , 40.25    , 39.68    , 39.55    ,
#        38.87    , 36.07    , 32.334   , 36.6167  , 40.72    , 38.32    ,
#        38.53    , 36.159   ])

# %%
df1 = pd.read_csv('/mnt/c/Users/Michael Anderson/Desktop/main_weather.csv')

# %%
df.to_csv('./random_weather.csv')

# %%
df2.drop(columns=['Unnamed: 0'], inplace=True)

# %% [markdown]
# DataFrame looks good, now we can plot the data we have retrieved:

# %%
df2
# Out:
#        year  precipitation_sum  precipitation_avg  precipitation_min  \
# 0      1941         795.199950           2.184615                0.0
# 1      1942         796.500000           2.188187                0.0
# 2      1943         740.000000           2.032967                0.0
# 3      1944         741.400000           2.031233                0.0
# 4      1945         878.100040           2.405754                0.0
# ...     ...                ...                ...                ...
# 18661  1987         771.300049           2.118956                0.0
# 18662  1988        1014.000000           2.778082                0.0
# 18663  1989         843.500000           2.317308                0.0
# 18664  1990         896.399963           2.462637                0.0
# 18665  1991         956.799927           2.628571                0.0
#
#        precipitation_max  temperature_sum  temperature_avg  temperature_min  \
# 0              32.600000     -1039.520100        -2.855825       -22.764832
# 1              24.199999     -1279.340800        -3.514673       -28.835660
# 2              25.300001      -893.180660        -2.453793       -29.969000
# 3              25.500000      -954.928830        -2.616243       -22.046083
# 4              30.000000     -1328.664100        -3.640176       -24.752329
# ...                  ...              ...              ...              ...
# 18661          24.699999      2490.460449         6.841924       -23.084665
# 18662          53.599998      2107.953125         5.775214       -21.743002
# 18663          34.400002      1911.473022         5.251299       -23.851334
# 18664          44.700001      1963.868774         5.395244       -19.890917
# 18665          34.700005      2205.145996         6.058094       -20.261749
#
#        temperature_max      lat       lon
# 0            16.620583  45.1667 -109.5167
# 1            15.106002  45.1667 -109.5167
# 2            15.399751  45.1667 -109.5167
# 3            14.287251  45.1667 -109.5167
# 4            14.799747  45.1667 -109.5167
# ...                ...      ...       ...
# 18661        26.373665  46.8600  -87.8000
# 18662        29.094503  46.8600  -87.8000
# 18663        26.900751  46.8600  -87.8000
# 18664        24.459082  46.8600  -87.8000
# 18665        27.788246  46.8600  -87.8000
#
# [18666 rows x 11 columns]

# %%
df2 = pd.concat([df1, df], ignore_index=True)

# %%
df2.to_csv('./main_weather.csv')

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(df['year'], df['precipitation_sum'])
plt.xlabel('Year')
plt.ylabel('Sum of Precipitation')
plt.title('Total Precipitation per Year')
plt.show()

# %%
plt.plot(df['year'], df['precipitation_daily_avg'])
plt.xlabel('Year')
plt.ylabel('Average Precipitation')
plt.title('Average Precipitation per Year')
plt.show()

# %%
df.to_csv('./weather_4.csv')

# %%
df = pd.read_csv('./weather_1.csv')
df1 = pd.read_csv('./weather_2.csv')
df2 = pd.read_csv('./weather_3.csv')
df3 = pd.read_csv('./weather_4.csv')

# %%
df
# Out:
#       Unnamed: 0  year  precipitation_sum  precipitation_avg  \
# 0              0  1941          795.19995           2.184615
# 1              1  1942          796.50000           2.188187
# 2              2  1943          740.00000           2.032967
# 3              3  1944          741.40000           2.031233
# 4              4  1945          878.10004           2.405754
# ...          ...   ...                ...                ...
# 5095        5095  1987          593.60000           1.630769
# 5096        5096  1988          651.20000           1.784110
# 5097        5097  1989          563.50000           1.548077
# 5098        5098  1990          688.40000           1.891209
# 5099        5099  1991          555.10004           1.525000
#
#       precipitation_min  precipitation_max  temperature_sum  temperature_avg  \
# 0                   0.0          32.600000      -1039.52010        -2.855825
# 1                   0.0          24.199999      -1279.34080        -3.514673
# 2                   0.0          25.300001       -893.18066        -2.453793
# 3                   0.0          25.500000       -954.92883        -2.616243
# 4                   0.0          30.000000      -1328.66410        -3.640176
# ...                 ...                ...              ...              ...
# 5095                0.0          17.400002        419.07250         1.151298
# 5096                0.0          21.500000        420.59094         1.152304
# 5097                0.0          20.999998        397.25586         1.091362
# 5098                0.0          45.599995        439.66223         1.207863
# 5099                0.0          19.699999        348.47240         0.957342
#
#       temperature_min  temperature_max      lat       lon
# 0          -22.764832        16.620583  45.1667 -109.5167
# 1          -28.835660        15.106002  45.1667 -109.5167
# 2          -29.969000        15.399751  45.1667 -109.5167
# 3          -22.046083        14.287251  45.1667 -109.5167
# 4          -24.752329        14.799747  45.1667 -109.5167
# ...               ...              ...      ...       ...
# 5095       -20.446000        17.837330  38.8000 -106.2300
# 5096       -23.462670        16.508165  38.8000 -106.2300
# 5097       -23.102247        19.541498  38.8000 -106.2300
# 5098       -21.202251        19.987333  38.8000 -106.2300
# 5099       -29.220999        16.168583  38.8000 -106.2300
#
# [5100 rows x 12 columns]

# %%
df.to_csv('./oaks.csv')

# %%
df
# Out:
#        Unnamed: 0  year  precipitation_sum  precipitation_avg  \
# 0               0  1941          795.19995           2.184615
# 1               1  1942          796.50000           2.188187
# 2               2  1943          740.00000           2.032967
# 3               3  1944          741.40000           2.031233
# 4               4  1945          878.10004           2.405754
# ...           ...   ...                ...                ...
# 18559        3259  1987          663.10000           1.821703
# 18560        3260  1988          742.30000           2.033699
# 18561        3261  1989          738.10004           2.027747
# 18562        3262  1990          700.80000           1.925275
# 18563        3263  1991          685.70000           1.883791
#
#        precipitation_min  precipitation_max  temperature_sum  temperature_avg  \
# 0                    0.0          32.600000      -1039.52010        -2.855825
# 1                    0.0          24.199999      -1279.34080        -3.514673
# 2                    0.0          25.300001       -893.18066        -2.453793
# 3                    0.0          25.500000       -954.92883        -2.616243
# 4                    0.0          30.000000      -1328.66410        -3.640176
# ...                  ...                ...              ...              ...
# 18559                0.0          22.300001       2280.62450         6.265452
# 18560                0.0          19.600002       2105.17720         5.767609
# 18561                0.0          26.600002       2474.67680         6.798563
# 18562                0.0          19.100002       2437.53080         6.696513
# 18563                0.0          18.400000       2185.29540         6.003559
#
#        temperature_min  temperature_max      lat       lon
# 0           -22.764832        16.620583  45.1667 -109.5167
# 1           -28.835660        15.106002  45.1667 -109.5167
# 2           -29.969000        15.399751  45.1667 -109.5167
# 3           -22.046083        14.287251  45.1667 -109.5167
# 4           -24.752329        14.799747  45.1667 -109.5167
# ...                ...              ...      ...       ...
# 18559       -13.539165        20.821253  36.1590 -105.5940
# 18560       -16.501665        19.696249  36.1590 -105.5940
# 18561       -16.466250        21.798334  36.1590 -105.5940
# 18562       -14.693333        22.475420  36.1590 -105.5940
# 18563       -23.216250        20.394167  36.1590 -105.5940
#
# [18564 rows x 12 columns]

# %%
df.to_csv('./main_weather.csv')

# %%
df = pd.read_csv('/mnt/c/Users/Michael Anderson/Desktop/main_weather.csv')

# %%
df.drop(['Unnamed: 0.1', 'Unnamed: 0'], axis=1, inplace=True)

# %%
df
# Out:
#        year  precipitation_sum  precipitation_avg  precipitation_min  \
# 0      1941          795.19995           2.184615                  0
# 1      1942          796.50000           2.188187                  0
# 2      1943          740.00000           2.032967                  0
# 3      1944          741.40000           2.031233                  0
# 4      1945          878.10004           2.405754                  0
# ...     ...                ...                ...                ...
# 18559  1987          663.10000           1.821703                  0
# 18560  1988          742.30000           2.033699                  0
# 18561  1989          738.10004           2.027747                  0
# 18562  1990          700.80000           1.925275                  0
# 18563  1991          685.70000           1.883791                  0
#
#        precipitation_max  temperature_sum  temperature_avg  temperature_min  \
# 0              32.600000      -1039.52010        -2.855825       -22.764832
# 1              24.199999      -1279.34080        -3.514673       -28.835660
# 2              25.300001       -893.18066        -2.453793       -29.969000
# 3              25.500000       -954.92883        -2.616243       -22.046083
# 4              30.000000      -1328.66410        -3.640176       -24.752329
# ...                  ...              ...              ...              ...
# 18559          22.300001       2280.62450         6.265452       -13.539165
# 18560          19.600002       2105.17720         5.767609       -16.501665
# 18561          26.600002       2474.67680         6.798563       -16.466250
# 18562          19.100002       2437.53080         6.696513       -14.693333
# 18563          18.400000       2185.29540         6.003559       -23.216250
#
#        temperature_max      lat       lon
# 0            16.620583  45.1667 -109.5167
# 1            15.106002  45.1667 -109.5167
# 2            15.399751  45.1667 -109.5167
# 3            14.287251  45.1667 -109.5167
# 4            14.799747  45.1667 -109.5167
# ...                ...      ...       ...
# 18559        20.821253  36.1590 -105.5940
# 18560        19.696249  36.1590 -105.5940
# 18561        21.798334  36.1590 -105.5940
# 18562        22.475420  36.1590 -105.5940
# 18563        20.394167  36.1590 -105.5940
#
# [18564 rows x 11 columns]

# %%
df.to_csv('main_weather.csv')

# %%
df = pd.read_csv('main_weather.csv')
df
# Out:
#       Unnamed: 0  year  precipitation_sum  precipitation_daily_avg  \
# 0              0  1970          938.90000                 2.579396
# 1              1  1971         1003.60000                 2.757143
# 2              2  1972          980.69995                 2.686849
# 3              3  1973          911.80000                 2.504945
# 4              4  1974          962.70000                 2.644780
# ...          ...   ...                ...                      ...
# 7639        7639  1986          839.50000                 2.306319
# 7640        7640  1987          652.10000                 1.791483
# 7641        7641  1988          730.40000                 2.001096
# 7642        7642  1989          731.80005                 2.010440
# 7643        7643  1990          690.40000                 1.896703
#
#       precipitation_min      lat       lon  precipitation_max
# 0                   0.0  45.1667 -109.5167          25.600000
# 1                   0.0  45.1667 -109.5167          30.999998
# 2                   0.0  45.1667 -109.5167          19.099998
# 3                   0.0  45.1667 -109.5167          26.700000
# 4                   0.0  45.1667 -109.5167          36.600000
# ...                 ...      ...       ...                ...
# 7639                0.0  36.1590 -105.5940          26.900000
# 7640                0.0  36.1590 -105.5940          18.200000
# 7641                0.0  36.1590 -105.5940          19.600002
# 7642                0.0  36.1590 -105.5940          26.600002
# 7643                0.0  36.1590 -105.5940          19.100002
#
# [7644 rows x 8 columns]

# %%
df.drop(['Unnamed: 0.1', 'Unnamed: 0'], axis=1, inplace=True)

# %%
df = pd.read_csv('/mnt/c/Users/Michael Anderson/Desktop/merged_oaks.csv')

# %%
df.drop(columns=[str(i) for i in range(1, 1941)], axis=1, inplace=True)

# %%
df = df.dropna(how='any')

# %%
df
#936 maples
#1906 firs
#6313 oaks
# Out:
#             index   1941   1942   1943   1944   1945   1946   1947   1948  \
# 46     067011_raw  0.970  1.090  1.110  1.070  1.130  1.280  1.080  1.150
# 47     084041_raw  2.780  3.060  2.590  2.270  2.060  2.590  1.540  1.660
# 48     065021_raw  3.510  4.160  3.010  3.030  3.360  3.180  2.840  2.540
# 49     078031_raw  2.350  3.080  1.730  3.310  2.350  3.110  1.920  1.610
# 50     070021_raw  1.570  2.000  1.520  1.720  1.370  1.880  1.630  1.880
# ...           ...    ...    ...    ...    ...    ...    ...    ...    ...
# 13359  TVR19b_raw  0.955  0.996  1.257  1.170  1.597  1.324  1.354  1.015
# 13360  TVR20a_raw  0.881  1.008  0.863  1.089  1.561  1.227  1.363  1.140
# 13361  TVR20b_raw  1.082  1.440  1.281  1.776  1.511  1.464  1.360  1.255
# 13362  TVR21a_raw  0.860  0.910  1.133  1.126  1.197  1.190  1.291  1.094
# 13363  TVR21b_raw  0.732  0.829  1.124  0.998  1.097  1.080  1.277  0.924
#
#         1949  ...   1989   1990   1991                        site  \
# 46     1.240  ...  1.260  1.260  0.930  Fernow Experimental Forest
# 47     2.110  ...  1.070  1.170  1.060  Fernow Experimental Forest
# 48     3.420  ...  1.200  1.320  1.210  Fernow Experimental Forest
# 49     2.300  ...  1.880  2.350  1.690  Fernow Experimental Forest
# 50     2.360  ...  0.860  0.870  0.750  Fernow Experimental Forest
# ...      ...  ...    ...    ...    ...                         ...
# 13359  0.860  ...  1.106  1.044  0.713             Goose Egg Ridge
# 13360  1.131  ...  1.800  1.397  1.288             Goose Egg Ridge
# 13361  1.037  ...  2.208  1.593  1.537             Goose Egg Ridge
# 13362  0.785  ...  1.218  0.893  0.762             Goose Egg Ridge
# 13363  0.823  ...  1.166  0.772  0.595             Goose Egg Ridge
#
#                  loc      N      S      E      W  species
# 46     West Virginia  39.10  39.10 -79.72 -79.72     QUPR
# 47     West Virginia  39.10  39.10 -79.72 -79.72     QUPR
# 48     West Virginia  39.10  39.10 -79.72 -79.72     QUPR
# 49     West Virginia  39.10  39.10 -79.72 -79.72     QUPR
# 50     West Virginia  39.10  39.10 -79.72 -79.72     QUPR
# ...              ...    ...    ...    ...    ...      ...
# 13359       New York  43.09  43.09 -73.39 -73.39     QURU
# 13360       New York  43.09  43.09 -73.39 -73.39     QURU
# 13361       New York  43.09  43.09 -73.39 -73.39     QURU
# 13362       New York  43.09  43.09 -73.39 -73.39     QURU
# 13363       New York  43.09  43.09 -73.39 -73.39     QURU
#
# [6204 rows x 59 columns]

# %%
df[['N', 'E']]
# Out:
#            N      E
# 46     39.10 -79.72
# 47     39.10 -79.72
# 48     39.10 -79.72
# 49     39.10 -79.72
# 50     39.10 -79.72
# ...      ...    ...
# 13359  43.09 -73.39
# 13360  43.09 -73.39
# 13361  43.09 -73.39
# 13362  43.09 -73.39
# 13363  43.09 -73.39
#
# [6204 rows x 2 columns]

# %%
df
